# %%
import pandas as pd
a = pd.read_csv("1-1-H2.csv",skiprows=6,header=None,usecols=[1,6,7,8], names=['时间','应力','应变1','应变2'])
a
# Out:
#          时间         应力       应变1           应变2
# 0    0.0005   1.991889  0.000010 -9.246575e-07
# 1    0.0006   2.013822  0.000012 -1.815068e-06
# 2    0.0008   2.095571  0.000013 -9.246575e-07
# 3    0.0010   2.095571  0.000013 -9.246575e-07
# 4    0.0012   2.177320  0.000016 -1.815068e-06
# ..      ...        ...       ...           ...
# 891  0.1549  95.431217  0.006629  3.049452e-03
# 892  0.1551  95.431217  0.006638  3.054931e-03
# 893  0.1552  95.451156  0.006645  3.060377e-03
# 894  0.1554  95.349468  0.006654  3.064931e-03
# 895  0.1556  95.205908  0.006659  3.070411e-03
#
# [896 rows x 4 columns]

# %%
import matplotlib as mpl
